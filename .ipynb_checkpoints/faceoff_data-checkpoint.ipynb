# %%
# Dependencies
#kaggle
import pandas as pd

# %%
# Store filepath in a variable
faceoff_data = "Resources/faceoff_data.csv"

# %%
faceoff_data_df = pd.read_csv(file_one)

# %%
faceoff_data_df
# Out:
#          game_id    season       game_start_time game_tz  play_id  game_time  \
# 0     2019020001  20192020  2019-10-02T23:00:00Z     EST        3          0
# 1     2019020001  20192020  2019-10-02T23:00:00Z     EST        3          0
# 2     2019020001  20192020  2019-10-02T23:00:00Z     EST        5         25
# 3     2019020001  20192020  2019-10-02T23:00:00Z     EST        5         25
# 4     2019020001  20192020  2019-10-02T23:00:00Z     EST        8         38
# ...          ...       ...                   ...     ...      ...        ...
# 7685  2019020984  20192020  2020-02-28T00:30:00Z     EST      293       3435
# 7686  2019020984  20192020  2020-02-28T00:30:00Z     EST      298       3456
# 7687  2019020984  20192020  2020-02-28T00:30:00Z     EST      298       3456
# 7688  2019020984  20192020  2020-02-28T00:30:00Z     EST      301       3527
# 7689  2019020984  20192020  2020-02-28T00:30:00Z     EST      301       3527
#
# ...

# %%
faceoff_data_df = faceoff_data_df.loc[faceoff_data_df["team"] == 'PHI']
faceoff_data_df.head(50)
# Out:
#          game_id    season       game_start_time game_tz  play_id  game_time  \
# 2151  2019020267  20192020  2019-11-11T00:00:00Z     EST        3          0
# 2153  2019020267  20192020  2019-11-11T00:00:00Z     EST       18        280
# 2155  2019020267  20192020  2019-11-11T00:00:00Z     EST       25        352
# 2157  2019020267  20192020  2019-11-11T00:00:00Z     EST       37        494
# 2159  2019020267  20192020  2019-11-11T00:00:00Z     EST       40        518
# 2161  2019020267  20192020  2019-11-11T00:00:00Z     EST       42        525
# 2163  2019020267  20192020  2019-11-11T00:00:00Z     EST       46        558
# 2165  2019020267  20192020  2019-11-11T00:00:00Z     EST       55        682
# 2167  2019020267  20192020  2019-11-11T00:00:00Z     EST       60        718
# 2169  2019020267  20192020  2019-11-11T00:00:00Z     EST       64        733
# 2171  2019020267  20192020  2019-11-11T00:00:00Z     EST       70        830
# ...

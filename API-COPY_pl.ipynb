# %%
import pandas as pd
import import_ipynb as ipynb
from faceoff__ import team_info
from Wiki_table import team_name, team_arena, team_name_
# Out:
# importing Jupyter notebook from faceoff__.ipynb
# importing Jupyter notebook from abbrevname.ipynb
# importing Jupyter notebook from Wiki_table.ipynb
# /Users/Kaboni/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:6393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = expressions.where(mask, this, that)

# %%
team_info
# Out:
#                  player team  win        city
# 0      Patrice Bergeron  BOS  708      Boston
# 1          David Krejci  BOS  342      Boston
# 2         Charlie Coyle  BOS  297      Boston
# 3           Sean Kuraly  BOS  240      Boston
# 4          Par Lindholm  BOS  123      Boston
# 5          Chris Wagner  BOS  114      Boston
# 6       Phillip Danault  MTL   40    Montreal
# 7           Jack Eichel  BUF   38     Buffalo
# 8        Leon Draisaitl  EDM   37    Edmonton
# 9   Jean-Gabriel Pageau  OTT   36      Ottawa
# 10        Sidney Crosby  PIT   33  Pittsburgh
# 11           Lars Eller  WSH   32  Washington
# 12       Jonathan Toews  CHI   32     Chicago
# 13      Auston Matthews  TOR   32     Toronto
# 14    Nicklas Backstrom  WSH   31  Washington

# %%
teams = team_name[['column1','column2']]
teams = teams.rename(columns={'column1': 'city', 'column2': 'teamname'})
teams
# Out:
#             city    teamname
# 0         Dallas       Stars
# 1       Colorado   Avalanche
# 2        Florida    Panthers
# 3       Montreal   Canadiens
# 4       Winnipeg        Jets
# 5      Nashville   Predators
# 6         Ottawa    Senators
# 7     Washington    Capitals
# 8            St.       Louis
# 9        Arizona     Coyotes
# 10       Anaheim       Ducks
# 11       Buffalo      Sabres
# 12       Detroit         Red
# 13           New        York
# 14           New        York
# 15      Columbus        Blue
# 16      Carolina  Hurricanes
# 17    Pittsburgh    Penguins
# 18           New      Jersey
# 19     Vancouver     Canucks
# 20      Edmonton      Oilers
# 21       Toronto       Maple
# 22       Calgary      Flames
# 23           San        Jose
# 24           Los     Angeles
# 25        Boston      Bruins
# 26         Vegas      Golden
# 27       Chicago  Blackhawks
# 28  Philadelphia      Flyers
# 29     Minnesota        Wild

# %%
full_team = pd.merge(team_info,teams, on='city', how='left')
full_team
# Out:
#                  player team  win        city    teamname
# 0      Patrice Bergeron  BOS  708      Boston      Bruins
# 1          David Krejci  BOS  342      Boston      Bruins
# 2         Charlie Coyle  BOS  297      Boston      Bruins
# 3           Sean Kuraly  BOS  240      Boston      Bruins
# 4          Par Lindholm  BOS  123      Boston      Bruins
# 5          Chris Wagner  BOS  114      Boston      Bruins
# 6       Phillip Danault  MTL   40    Montreal   Canadiens
# 7           Jack Eichel  BUF   38     Buffalo      Sabres
# 8        Leon Draisaitl  EDM   37    Edmonton      Oilers
# 9   Jean-Gabriel Pageau  OTT   36      Ottawa    Senators
# 10        Sidney Crosby  PIT   33  Pittsburgh    Penguins
# 11           Lars Eller  WSH   32  Washington    Capitals
# 12       Jonathan Toews  CHI   32     Chicago  Blackhawks
# 13      Auston Matthews  TOR   32     Toronto       Maple
# 14    Nicklas Backstrom  WSH   31  Washington    Capitals

# %%
team_name_ = team_name_.rename(columns={'column1': 'city', 'team_name': 'teamname'})
team_name_
# Out:
#         city        teamname
# 8        St.     Louis Blues
# 12   Detroit       Red Wings
# 13       New    York Rangers
# 14       New  York Islanders
# 15  Columbus    Blue Jackets
# 18       New   Jersey Devils
# 21   Toronto     Maple Leafs
# 23       San     Jose Sharks
# 24       Los   Angeles Kings
# 26     Vegas  Golden Knights

# %%
toronto = team_name_.loc[team_name_['city'] == 'Toronto']
toronto
# Out:
#        city     teamname
# 21  Toronto  Maple Leafs

# %%
full_player_info = pd.merge(team_info,toronto, on='city',how='left')
full_player_info
# Out:
#                  player team  win        city     teamname
# 0      Patrice Bergeron  BOS  708      Boston          NaN
# 1          David Krejci  BOS  342      Boston          NaN
# 2         Charlie Coyle  BOS  297      Boston          NaN
# 3           Sean Kuraly  BOS  240      Boston          NaN
# 4          Par Lindholm  BOS  123      Boston          NaN
# 5          Chris Wagner  BOS  114      Boston          NaN
# 6       Phillip Danault  MTL   40    Montreal          NaN
# 7           Jack Eichel  BUF   38     Buffalo          NaN
# 8        Leon Draisaitl  EDM   37    Edmonton          NaN
# 9   Jean-Gabriel Pageau  OTT   36      Ottawa          NaN
# 10        Sidney Crosby  PIT   33  Pittsburgh          NaN
# 11           Lars Eller  WSH   32  Washington          NaN
# 12       Jonathan Toews  CHI   32     Chicago          NaN
# 13      Auston Matthews  TOR   32     Toronto  Maple Leafs
# 14    Nicklas Backstrom  WSH   31  Washington          NaN

# %%
full_data = full_player_info.fillna(full_team)
full__data = full_data[:11]

# %%
full__data["Team(s)"] = full__data["city"] + " " + full__data["teamname"]
full__data
# Out:
# <ipython-input-60-40e8be5ad227>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full__data["Team(s)"] = full__data["city"] + " " + full__data["teamname"]
#                  player team  win        city   teamname              Team(s)
# 0      Patrice Bergeron  BOS  708      Boston     Bruins        Boston Bruins
# 1          David Krejci  BOS  342      Boston     Bruins        Boston Bruins
# 2         Charlie Coyle  BOS  297      Boston     Bruins        Boston Bruins
# 3           Sean Kuraly  BOS  240      Boston     Bruins        Boston Bruins
# 4          Par Lindholm  BOS  123      Boston     Bruins        Boston Bruins
# 5          Chris Wagner  BOS  114      Boston     Bruins        Boston Bruins
# ...

# %%
PTA_df = pd.merge(full__data,team_arena, on='Team(s)', how='left')
PTA_df
# Out:
#                  player team  win        city   teamname              Team(s)  \
# 0      Patrice Bergeron  BOS  708      Boston     Bruins        Boston Bruins
# 1          David Krejci  BOS  342      Boston     Bruins        Boston Bruins
# 2         Charlie Coyle  BOS  297      Boston     Bruins        Boston Bruins
# 3           Sean Kuraly  BOS  240      Boston     Bruins        Boston Bruins
# 4          Par Lindholm  BOS  123      Boston     Bruins        Boston Bruins
# 5          Chris Wagner  BOS  114      Boston     Bruins        Boston Bruins
# 6       Phillip Danault  MTL   40    Montreal  Canadiens   Montreal Canadiens
# 7           Jack Eichel  BUF   38     Buffalo     Sabres       Buffalo Sabres
# 8        Leon Draisaitl  EDM   37    Edmonton     Oilers      Edmonton Oilers
# 9   Jean-Gabriel Pageau  OTT   36      Ottawa   Senators      Ottawa Senators
# 10        Sidney Crosby  PIT   33  Pittsburgh   Penguins  Pittsburgh Penguins
#
#                    Arena
# ...

# %%
city_list = []
for x in PTA_df['city']:
    city_list.append(x)
city_list
# Out:
# ['Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Montreal',
#  'Buffalo',
#  'Edmonton',
#  'Ottawa',
#  'Pittsburgh']

# %%
city_df = pd.DataFrame(city_list, columns =['city'])
city_df
# Out:
#           city
# 0       Boston
# 1       Boston
# 2       Boston
# 3       Boston
# 4       Boston
# 5       Boston
# 6     Montreal
# 7      Buffalo
# 8     Edmonton
# 9       Ottawa
# 10  Pittsburgh

# %%
city_df__ = city_df.drop_duplicates(subset=['city'])
city_df__
# Out:
#           city
# 0       Boston
# 6     Montreal
# 7      Buffalo
# 8     Edmonton
# 9       Ottawa
# 10  Pittsburgh

# %%
import time
city_city = []
for city in city_df__['city']:
    city_city.append(city)
    
# citycity = ['Boston', 'Philadelphia']
# for team in citycity:
#     print(team)
#     time.sleep(1)
city_city

# %%
# Dependencies
import requests
import json
from pprint import pprint
from config import gkey
import time

# citycity = ['Boston', 'Philadelphia']
# city_name = []
#for team in city_city:
    #print(team)
    #time.sleep(1)
#putting a target city to find its coordinates
#for city in city_df__:
target_city = "Boston"

# Build the endpoint URL
target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&key={1}').format(target_city, gkey)

# # # Run a request to endpoint and convert result to json
# geo_data = requests.get(target_url).json()
# place = geo_data["results"][0]['address_components'][0]['long_name']



# # # Print the json
# # pprint(geo_data)
# # break

# # # Extracting the latitude and longitude to plug into nearby search
# lat = geo_data["results"][0]["geometry"]['bounds']['northeast']["lat"]
# lng = geo_data["results"][0]["geometry"]["bounds"]['northeast']["lng"]



# # # setting the geocoordinates to find the stadium
# target_coordinates = f"{lat}, {lng}"
# target_radius = 50000
# target_type = "stadium"

# # # set up a parameters dictionary
# params = {
#     "location": target_coordinates,
#     "radius": target_radius,
#     "type": target_type,
#     "key": gkey
# }

# # # base url
# base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# # # run a request using our params dictionary
# response = requests.get(base_url, params=params)

# # # convert response to json
# places_data = response.json()

# # # Print the json (pretty printed)
# # #pprint(places_data)

# # # Print the name and address of the first restaurant that appears
# stadium__ = places_data["results"][1]["name"]

# city_name.append({"city":place,
#                  "lat":lat,
#                  "lng":lng,
#                  "stadium":stadium__})
# time.sleep(10)
# # break

# # stadium_list
# city_name

# %%
for city in city_list:
    target_city = city
    #print(target_city)

    # Build the endpoint URL
    target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
        'address={0}&key={1}').format(target_city, gkey)
    geo_data = requests.get(target_url).json()
    place_list.append(geo_data["results"][0]['address_components'][0]['long_name'])
    lat = geo_data["results"][0]["geometry"]['bounds']['northeast']["lat"]
    lng = geo_data["results"][0]["geometry"]["bounds"]['northeast']["lng"]
    #print(f"{lat}, {lng}")
    
    # setting the geocoordinates to find the stadium
    target_coordinates = f"{lat}, {lng}"
    target_radius = 50000
    target_type = "stadium"

    # set up a parameters dictionary
    params = {
        "location": target_coordinates,
        "radius": target_radius,
        "type": target_type,
        "key": gkey
    }

    # base url
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # run a request using our params dictionary
    response = requests.get(base_url, params=params)
    places_data = response.json()
    
    coordinates_list = []
    lat_list = []
    lng_list= []
    #x = 0
    for arena in PTA_df['Arena']:
        x = 0
        if places_data["results"][x]["name"] == arena:
            latt = places_data["results"][x]["geometry"]["location"]["lat"]
            print(latt)
            lngg = places_data["results"][x]["geometry"]["location"]["lng"]
        else:
            x += 1
        coordinates_list.append({"Arena": arena,
                            "lat_lng": f"{latt}, {lngg}"})
    #break
coordinates_list
# Out:
# [{'Arena': 'TD Garden', 'lat_lng': '42.366198, -71.062146'},
#  {'Arena': 'TD Garden', 'lat_lng': '42.366198, -71.062146'},
#  {'Arena': 'TD Garden', 'lat_lng': '42.366198, -71.062146'},
#  {'Arena': 'TD Garden', 'lat_lng': '42.366198, -71.062146'},
#  {'Arena': 'TD Garden', 'lat_lng': '42.366198, -71.062146'},
#  {'Arena': 'TD Garden', 'lat_lng': '42.366198, -71.062146'},
#  {'Arena': 'Bell Centre', 'lat_lng': '42.366198, -71.062146'},
#  {'Arena': 'KeyBank Center', 'lat_lng': '42.366198, -71.062146'},
#  {'Arena': 'Rogers Place', 'lat_lng': '42.366198, -71.062146'},
#  {'Arena': 'Canadian Tire Centre', 'lat_lng': '42.366198, -71.062146'},
#  {'Arena': 'PPG Paints Arena', 'lat_lng': '42.366198, -71.062146'}]

# %%
  latt = places_data["results"][x]["geometry"]["location"]["lat"]
            print(latt)
            lngg = places_data["results"][x]["geometry"]["location"]["lng"]
        else:
            x += 1
        coordinates_list.append({"Arena": arena,
                            "lat_lng": f"{latt}, {lngg}"})
    #break
coordinates_list

# %%
dict_df = pd.DataFrame(coordinates_list)
dict_df
# Out:
#                    Arena                lat_lng
# 0              TD Garden  42.366198, -71.062146
# 1              TD Garden  42.366198, -71.062146
# 2              TD Garden  42.366198, -71.062146
# 3              TD Garden  42.366198, -71.062146
# 4              TD Garden  42.366198, -71.062146
# 5              TD Garden  42.366198, -71.062146
# 6            Bell Centre  42.366198, -71.062146
# 7         KeyBank Center  42.366198, -71.062146
# 8           Rogers Place  42.366198, -71.062146
# 9   Canadian Tire Centre  42.366198, -71.062146
# 10      PPG Paints Arena  42.366198, -71.062146

# %%
dict_df_dd = dict_df.drop_duplicates(subset=['Arena'])
dict_df_dd
# Out:
#                    Arena                lat_lng
# 0              TD Garden  42.366198, -71.062146
# 6            Bell Centre  42.366198, -71.062146
# 7         KeyBank Center  42.366198, -71.062146
# 8           Rogers Place  42.366198, -71.062146
# 9   Canadian Tire Centre  42.366198, -71.062146
# 10      PPG Paints Arena  42.366198, -71.062146

# %%
PTALL_df = pd.merge(PTA_df,dict_df_dd, on='Arena', how='left')
PTALL_df
# Out:
#                  player team  win        city   teamname              Team(s)  \
# 0      Patrice Bergeron  BOS  708      Boston     Bruins        Boston Bruins
# 1          David Krejci  BOS  342      Boston     Bruins        Boston Bruins
# 2         Charlie Coyle  BOS  297      Boston     Bruins        Boston Bruins
# 3           Sean Kuraly  BOS  240      Boston     Bruins        Boston Bruins
# 4          Par Lindholm  BOS  123      Boston     Bruins        Boston Bruins
# 5          Chris Wagner  BOS  114      Boston     Bruins        Boston Bruins
# 6       Phillip Danault  MTL   40    Montreal  Canadiens   Montreal Canadiens
# 7           Jack Eichel  BUF   38     Buffalo     Sabres       Buffalo Sabres
# 8        Leon Draisaitl  EDM   37    Edmonton     Oilers      Edmonton Oilers
# 9   Jean-Gabriel Pageau  OTT   36      Ottawa   Senators      Ottawa Senators
# 10        Sidney Crosby  PIT   33  Pittsburgh   Penguins  Pittsburgh Penguins
#
# ...

# %%
for cord in PTALL_df['lat_lng']:

# %%
# setting the geocoordinates to find the stadium
target_coordinates = "42.366198, -71.062146"
target_radius = 50000
target_type = "restaurant"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)
places_data = response.json()

places_data['results'][0]['name']
# Out:
# 'Royal Sonesta Boston'

# %%
coordinates_list = []
    x = 0
    for arena in PTA_df['Arena']:
        if places_data["results"][x]["name"] == arena:
            latt = places_data["results"][x]["geometry"]["location"]["lat"]
            lngg = places_data["results"][x]["geometry"]["location"]["lng"]
        coordinates_list.append({"Arena": arena,
                                    "lat_lng": f"{latt}, {lngg}"})
        #else:
        x+=1
    #break
coordinates_list

# %%
target_city = 'Pittsburgh'
target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
        'address={0}&key={1}').format(target_city, gkey)
# Run a request to endpoint and convert result to json
geo_data = requests.get(target_url).json()

# Print the json
pprint(geo_data)
# Out:
# {'results': [{'address_components': [{'long_name': 'Pittsburgh',
#                                       'short_name': 'Pittsburgh',
#                                       'types': ['locality', 'political']},
#                                      {'long_name': 'Allegheny County',
#                                       'short_name': 'Allegheny County',
#                                       'types': ['administrative_area_level_2',
#                                                 'political']},
#                                      {'long_name': 'Pennsylvania',
#                                       'short_name': 'PA',
#                                       'types': ['administrative_area_level_1',
#                                                 'political']},
#                                      {'long_name': 'United States',
#                                       'short_name': 'US',
#                                       'types': ['country', 'political']}],
# ...

# %%
place = geo_data["results"][0]['address_components'][0]['long_name']
place
# Out:
# 'Pittsburgh'

# %%
# Extracting the latitude and longitude to plug into nearby search
lat = geo_data["results"][0]["geometry"]['bounds']['northeast']["lat"]
lng = geo_data["results"][0]["geometry"]["bounds"]['northeast']["lng"]

# %%
# setting the geocoordinates to find the stadium
target_coordinates = f"{lat}, {lng}"
target_radius = 70000
target_type = "stadium"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
# convert response to json
places_data = response.json()

# Print the json (pretty printed)
pprint(places_data)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'ATtYBwKcWAhKTsxADyKZE_Kuz6THTgeSK5zfwXsT8HRUUTy1s2EECtAnw91CHtpMcBzhtEng3or1auEYPuhEAwYPoR3oHV4qczH2lYakwJ1qdHh-U_dGfEfMPVQUMJCiJb9UlcgKTVls84iVyACCbULH-qnSD0ozfRzZre4KWaWH--ljZd9GSr4mBZn-knfas9BRTYunae-VoQigYGqLBeZgnY6_WG7KqA7qrSs9RmZFtw1wVIMbEf7VPXP_zdzK8cuRu_rv9ngx4BIcMBG4M3QW-Tv-UStPaoNdJPapV49q17FHLnGVBk_tmnTxTJ1JaOw1pbV9aPPlIjfO03SLMbw7w_XGVyRuYlaLzAh4wy2NDGpjWMRTQp7zcQ-7svzBFlg_geDYVjwgmNBXuw-pv2lTez1UiY1GGl3a3Egqmed9rEzl43qzXb1ONsxl',
#  'results': [{'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 40.4467648, 'lng': -80.0157603},
#                            'viewport': {'northeast': {'lat': 40.44892589999999,
#                                                       'lng': -80.01269780000001},
#                                         'southwest': {'lat': 40.44478590000001,
#                                                       'lng': -80.01943819999998}}},
# ...

# %%
# Print the name and address of the first restaurant that appears
coordinate_list = []
x = 0
for arena in PTA_df['Arena']:
    if places_data["results"][x]["name"] == arena:
        latt = places_data["results"][x]["geometry"]["location"]["lat"]
        lngg = places_data["results"][x]["geometry"]["location"]["lng"]
        coordinate_list.append(f"{latt}, {lngg}")
    else:
        x+=1
        

coordinate_list
# Out:
# []

# %%
#flyers_stadium = places_data["results"][0]["name"]
flyers_stadium

# %%
x=0
stad_list = []
while x<(len(team_info)):
    
    stad_list.append(flyers_stadium)
    x+=1
stad_list

# %%
sdf = pd.DataFrame(stad_list)

# %%
sdf.count()

# %%
team_info.count()

# %%
flyer_info = team_info.join(sdf)
flyer_info

# %%
flyer_info = flyer_info.rename(columns={0: 'stadium'})

# %%
flyer_info
